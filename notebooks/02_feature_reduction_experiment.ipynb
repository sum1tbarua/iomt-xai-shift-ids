# %% [markdown]
# # Import Dependenices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# %% [markdown]
# # Dataset Load

# %%
train_df = pd.read_csv("datasets/CICIOMT/train/ciciomt2024_train_balanced.csv")
val_df = pd.read_csv("datasets/CICIOMT/val/ciciomt2024_validation_balanced.csv")
test_df = pd.read_csv("datasets/CICIOMT/test/ciciomt2024_test_balanced.csv")

# %% [markdown]
# # Define feature columns and target label

# %%
non_feature_cols = [
    "source_file",
    "attack_type",
    "binary_label"
]

feature_cols = [col for col in train_df.columns if col not in non_feature_cols]
target_label = "binary_label"

# %% [markdown]
# # XGBoost Training

# %%
# XGBoost model
xgb = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    eval_metric='logloss'
)

# train
xgb.fit(X_train, y_train)

# %% [markdown]
# # Top-20 Feature Ranking

# %%
# Get feature importance from trained XGBoost model
importance_values = xgb.feature_importances_

# Create Dataframe
importance_df = pd.DataFrame({
    "feature": feature_cols,
    "importance": importance_values
})

# Sort by importance
importance_df = importance_df.sort_values(by="importance", ascending=False)

# Show top 20 features
print(importance_df.head(20))

# Plot top 20 features
top20 = importance_df.head(20)
plt.figure(figsize=(10, 6))
plt.barh(top20["feature"], top20["importance"])
plt.gca().invert_yaxis()
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 20 XGBoost Feature Importances")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top-20 Feature Experiment

# %%
top20_features = importance_df.head(20)["feature"].tolist()

X_train_top20 = X_train[top20_features]
X_val_top20 = X_val[top20_features]
X_test_top20 = X_test[top20_features]

xgb_top20 = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss"
)

xgb_top20.fit(X_train_top20, y_train)


y_val_pred = xgb_top20.predict(X_val_top20)
print("Top-20 XGBoost Validation Metrics:")
print("Accuracy:", accuracy_score(y_val, y_val_pred))
print("Precision:", precision_score(y_val, y_val_pred))
print("Recall:", recall_score(y_val, y_val_pred))
print("F1:", f1_score(y_val, y_val_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))

y_test_pred = xgb_top20.predict(X_test_top20)

print("\n\nTop-20 XGBoost Test Metrics:")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print("Precision:", precision_score(y_test, y_test_pred))
print("Recall:", recall_score(y_test, y_test_pred))
print("F1:", f1_score(y_test, y_test_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))

# %% [markdown]
# # Top-10 Feature Experiment

# %%
top10_features = importance_df.head(10)["feature"].tolist()
X_train_top10 = X_train[top10_features]
X_val_top10 = X_val[top10_features]
X_test_top10 = X_test[top10_features]

xgb_top10 = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss"
)

xgb_top10.fit(X_train_top10, y_train)

y_val_pred = xgb_top10.predict(X_val_top10)
print("Top-10 XGBoost Validation Metrics:")
print("Accuracy:", accuracy_score(y_val, y_val_pred))
print("Precision:", precision_score(y_val, y_val_pred))
print("Recall:", recall_score(y_val, y_val_pred))
print("F1:", f1_score(y_val, y_val_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))

y_test_pred = xgb_top10.predict(X_test_top10)

print("\n\nTop-10 XGBoost Test Metrics:")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print("Precision:", precision_score(y_test, y_test_pred))
print("Recall:", recall_score(y_test, y_test_pred))
print("F1:", f1_score(y_test, y_test_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))

# %% [markdown]
# # Top-5 Feature Experiment

# %%
top5_features = importance_df.head(5)["feature"].tolist()
X_train_top5 = X_train[top5_features]
X_val_top5 = X_val[top5_features]
X_test_top5 = X_test[top5_features]

xgb_top5 = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss"
)

xgb_top5.fit(X_train_top5, y_train)

y_val_pred = xgb_top5.predict(X_val_top5)
print("Top-5 XGBoost Validation Metrics:")
print("Accuracy:", accuracy_score(y_val, y_val_pred))
print("Precision:", precision_score(y_val, y_val_pred))
print("Recall:", recall_score(y_val, y_val_pred))
print("F1:", f1_score(y_val, y_val_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))

y_test_pred = xgb_top5.predict(X_test_top5)

print("\n\nTop-5 XGBoost Test Metrics:")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print("Precision:", precision_score(y_test, y_test_pred))
print("Recall:", recall_score(y_test, y_test_pred))
print("F1:", f1_score(y_test, y_test_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))

# %% [markdown]
# #

# %% [markdown]
# #
